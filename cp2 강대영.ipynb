# %%
from google.colab import drive
drive.mount("/content/MyDrive/")
# Out:
# Mounted at /content/MyDrive/

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
filename = '/content/MyDrive/MyDrive/codestates/cp2/2019-Oct.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
df.shape
# Out:
# (42448764, 9)

# %%
df['event_type'].unique()
# Out:
# array(['view', 'purchase', 'cart'], dtype=object)

# %%
df['user_id'].value_counts()
# Out:
# 512475445    7436
# 512365995    4013
# 526731152    2912
# 512505687    2894
# 513021392    2862
#              ...
# 556920045       1
# 521755468       1
# 515083572       1
# 549391147       1
# 544578298       1
# Name: user_id, Length: 3022290, dtype: int64

# %%
condition = df.event_type == 'purchase' # 구매 타입 데이터프레임
df_pca = df[condition]
df_pca.head()
# Out:
#                   event_time event_type  product_id          category_id  \
# 162  2019-10-01 00:02:14 UTC   purchase     1004856  2053013555631882655
# 308  2019-10-01 00:04:37 UTC   purchase     1002532  2053013555631882655
# 379  2019-10-01 00:06:02 UTC   purchase     5100816  2053013553375346967
# 442  2019-10-01 00:07:07 UTC   purchase    13800054  2053013557418656265
# 574  2019-10-01 00:09:26 UTC   purchase     4804055  2053013554658804075
#
#                    category_code    brand   price    user_id  \
# 162       electronics.smartphone  samsung  130.76  543272936
# 308       electronics.smartphone    apple  642.69  551377651
# 379                          NaN   xiaomi   29.51  514591159
# 442    furniture.bathroom.toilet  santeri   54.42  555332717
# 574  electronics.audio.headphone    apple  189.91  524601178
#
#                              user_session
# 162  8187d148-3c41-46d4-b0c0-9c08cd9dc564
# 308  3c80f0d6-e9ec-4181-8c5c-837a30be2d68
# ...

# %%
a = df_pca.loc[162:574,['user_id','event_type','price']]
a
# Out:
#        user_id event_type   price
# 162  543272936   purchase  130.76
# 308  551377651   purchase  642.69
# 379  514591159   purchase   29.51
# 442  555332717   purchase   54.42
# 574  524601178   purchase  189.91

# %%
df_pca['user_id'].count
# Out:
# <bound method Series.count of 162         543272936
# 308         551377651
# 379         514591159
# 442         555332717
# 574         524601178
#               ...
# 42448148    516604399
# 42448173    514622109
# 42448271    512717356
# 42448362    533892594
# 42448657    544501248
# Name: user_id, Length: 742849, dtype: int64>

# %%
df_pca[df_pca['user_id'] == 524601178].count()
# Out:
# event_time       1
# event_type       1
# product_id       1
# category_id      1
# category_code    1
# brand            1
# price            1
# user_id          1
# user_session     1
# dtype: int64

# %%
df_pca.loc[574:574,:]
# Out:
#                   event_time event_type  product_id          category_id  \
# 574  2019-10-01 00:09:26 UTC   purchase     4804055  2053013554658804075
#
#                    category_code  brand   price    user_id  \
# 574  electronics.audio.headphone  apple  189.91  524601178
#
#                              user_session
# 574  2af9b570-0942-4dcd-8f25-4d84fba82553

# %%
b = df_pca.loc[[162,308,379,442,574],'event_time']
b
# Out:
# 162    2019-10-01 00:02:14 UTC
# 308    2019-10-01 00:04:37 UTC
# 379    2019-10-01 00:06:02 UTC
# 442    2019-10-01 00:07:07 UTC
# 574    2019-10-01 00:09:26 UTC
# Name: event_time, dtype: object

# %%
a['frequency'] = [34,15,1,5,1]

# %%
a['recency'] = b
a
# Out:
#        user_id event_type   price  frequency                  recency
# 162  543272936   purchase  130.76         34  2019-10-01 00:02:14 UTC
# 308  551377651   purchase  642.69         15  2019-10-01 00:04:37 UTC
# 379  514591159   purchase   29.51          1  2019-10-01 00:06:02 UTC
# 442  555332717   purchase   54.42          5  2019-10-01 00:07:07 UTC
# 574  524601178   purchase  189.91          1  2019-10-01 00:09:26 UTC

# %%
df_pca[df_pca['user_id'] == 543272936]['price'].sum()
df_pca[df_pca['user_id'] == 551377651]['price'].sum()
df_pca[df_pca['user_id'] == 514591159]['price'].sum()
df_pca[df_pca['user_id'] == 555332717]['price'].sum()
df_pca[df_pca['user_id'] == 524601178]['price'].sum()
# Out:
# 189.91

# %%
a['monetary'] = [4432.08, 4883.16, 29.51, 244.75, 189.91]

# %%
a
# Out:
#        user_id event_type   price  frequency                  recency  \
# 162  543272936   purchase  130.76         34  2019-10-01 00:02:14 UTC
# 308  551377651   purchase  642.69         15  2019-10-01 00:04:37 UTC
# 379  514591159   purchase   29.51          1  2019-10-01 00:06:02 UTC
# 442  555332717   purchase   54.42          5  2019-10-01 00:07:07 UTC
# 574  524601178   purchase  189.91          1  2019-10-01 00:09:26 UTC
#
#      monetary
# 162   4432.08
# 308   4883.16
# 379     29.51
# 442    244.75
# 574    189.91

# %%
df[event_type].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-49dd402f5dfa> in <module>()
# ----> 1 df[event_type].count()
#
# NameError: name 'event_type' is not defined

# %%
df_pca.shape # 구매 데이터프레임 행렬 개수
# Out:
# (742849, 9)

# %%
df_view = df[df.event_type == 'view'] # 뷰 타입 데이터프레임
df_view.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       view    44600062  2103807459595387724
# 1  2019-10-01 00:00:00 UTC       view     3900821  2053013552326770905
# 2  2019-10-01 00:00:01 UTC       view    17200506  2053013559792632471
# 3  2019-10-01 00:00:01 UTC       view     1307067  2053013558920217191
# 4  2019-10-01 00:00:04 UTC       view     1004237  2053013555631882655
#
#                          category_code     brand    price    user_id  \
# 0                                  NaN  shiseido    35.79  541312140
# 1  appliances.environment.water_heater      aqua    33.20  554748717
# 2           furniture.living_room.sofa       NaN   543.10  519107250
# 3                   computers.notebook    lenovo   251.74  550050854
# 4               electronics.smartphone     apple  1081.98  535871217
#
#                            user_session
# 0  72d76fde-8bb3-4e00-8c23-a032dfed738c
# 1  9333dfbd-b87a-4708-9857-6336556b0fcc
# ...

# %%
list_pca_user = df_pca['user_id'].unique()
list_pca_user
list_price = []
for a in range(0,100001) :
  list_price.append(df_pca[df_pca['user_id'] == list_pca_user[a]]['price'].sum())
list_price[2]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-7c009359cdbd> in <module>()
#       3 list_price = []
#       4 for a in range(0,100001) :
# ----> 5   list_price.append(df_pca[df_pca['user_id'] == list_pca_user[a]]['price'].sum())
#       6 list_price[2]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3447         # Do we have a (boolean) 1d indexer?
#    3448         if com.is_bool_indexer(key):
# -> 3449             return self._getitem_bool_array(key)
#    3450
#    3451         # We are left with two options: a single key, and a collection of keys,
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3501         # be reindexed to match DataFrame rows
#    3502         key = check_bool_indexer(self.index, key)
# -> 3503         indexer = key.nonzero()[0]
# ...

# %%
print(df_pca.loc[df_pca['user_id'] == 551377651,'price'].sum())
# Out:
# 4833.169999999999

# %%
df_pca[df_pca['user_id'] == 551377651]['price'].sum()
# Out:
# 4833.169999999999

# %%
a = df_pca['user_id'].unique()
df_pca[df_pca['user_id'] == a[0]]['price'].sum()
# Out:
# 4432.08

# %%
list_pca_user = df_pca['user_id'].unique()
list_pca_user
# Out:
# array([543272936, 551377651, 514591159, ..., 514905226, 544501248,
#        516662286])

# %%
len(list_pca_user)
# Out:
# 347118
